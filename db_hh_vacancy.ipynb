# %% [markdown]
# 1. Развернуть у себя на компьютере/виртуальной машине/хостинге MongoDB и реализовать функцию, которая будет добавлять только новые вакансии/продукты в вашу базу.
# 2. Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введённой суммы (необходимо анализировать оба поля зарплаты). Для тех, кто выполнил задание с Росконтролем - напишите запрос для поиска продуктов с рейтингом не ниже введенного или качеством не ниже введенного (то есть цифра вводится одна, а запрос проверяет оба поля).

# %% [markdown]
# Файл с запросом на наименование поискового запроса для добавления в БД MongoDB и фукнцией поиска вакансий по заработной плате

# %%
import nbimporter
import requests
import json
from lxml import html
from bs4 import BeautifulSoup as bs
from time import sleep
import pandas as pd
from hh_parser import * #функции для парсинга сайта hh и записи данных в БД MongoDB
from pymongo import MongoClient
from pprint import pprint

# %%
def search_vacances_with_salary_more_then_input_sum(db, salary_sum):
    vacances_with_min_max_salary_more_then_input_sum = db.hh.find({
                'min_salary': {'$gt': salary_sum}, 
                'max_salary': {'$gt': salary_sum}})
    
    for doc in vacances_with_min_max_salary_more_then_input_sum:
          pprint(doc)

# %%
search_text = input('Введите название вакансии для поиска и занесение в базу данных: ')
# Out:
# Введите название вакансии для поиска и занесение в базу данных: Уборщик

# %%
client = MongoClient()

# %%
db = client.vacances_db

# %%
hh_search_parsing_db_writing(search_text, db)

# %%
#client.drop_database('vacances_db')

# %%
salary_sum = float(input('Введите сумму заработной платы для поиска вакансий с большей сумма ЗП: '))
search_vacances_with_salary_more_then_input_sum(db, salary_sum)
# Out:
# Введите сумму заработной платы для поиска вакансий с большей сумма ЗП: 50000
# {'_id': ObjectId('63f227e0f2084d20c468e339'),
#  'adress': 'Москва, Аэропорт и еще\xa02\xa0',
#  'currency': 'руб.',
#  'date_search': datetime.datetime(2023, 2, 19, 16, 45, 4, 508000),
#  'employer': 'ООО\xa0Группа компаний Альфа',
#  'employer_url': 'https://hh.ru/employer/4669605?hhtmFrom=vacancy_search_list',
#  'hh_site': True,
#  'max_salary': 150000.0,
#  'min_salary': 80500.0,
#  'search_name': 'авиаконструктор',
#  'short_description_of_vacancy': None,
#  'vacancy_name': 'Менеджер по закупкам',
#  'vacancy_url': 'https://hh.ru/vacancy/76988114?from=vacancy_search_list&query=%D0%B0%D0%B2%D0%B8%D0%B0%D0%BA%D0%BE%D0%BD%D1%81%D1%82%D1%80%D1%83%D0%BA%D1%82%D0%BE%D1%80'}
# {'_id': ObjectId('63f227e0f2084d20c468e33a'),
#  'adress': 'Москва, Аэропорт и еще\xa02\xa0',
#  'currency': 'руб.',
#  'date_search': datetime.datetime(2023, 2, 19, 16, 45, 4, 509000),
#  'employer': 'ООО\xa0Группа компаний Альфа',
# ...
