# %% [markdown]
# 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
import requests
from pprint import pprint
import json

# %%
url = 'https://api.github.com/users/chapayM/repos'

r = requests.get(url=url)
print(r.status_code)
# Out:
# 200

# %%
pprint(r.json())
# Out:
# [{'allow_forking': True,
#   'archive_url': 'https://api.github.com/repos/chapayM/algorytms/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/chapayM/algorytms/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/chapayM/algorytms/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/chapayM/algorytms/branches{/branch}',
#   'clone_url': 'https://github.com/chapayM/algorytms.git',
#   'collaborators_url': 'https://api.github.com/repos/chapayM/algorytms/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/chapayM/algorytms/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/chapayM/algorytms/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/chapayM/algorytms/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/chapayM/algorytms/contents/{+path}',
# ...

# %%
repos_names = []
for el in r.json():
    repos_names.append(el['name'])
print(repos_names)
# Out:
# ['algorytms', 'basics_python', 'codewars', 'pandas_numpy_mathprolib', 'ucheda_data_liens']

# %%
data = {'user':'chapayM',
       'repositories': repos_names}

# %%
with open('data.json', 'w') as outfile:
    json.dump(data, outfile)

# %% [markdown]
# 2. Изучить список открытых API (https://www.programmableweb.com/category/all/apis). Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.
# Если нет желания заморачиваться с поиском, возьмите API вконтакте (https://vk.com/dev/first_guide). Сделайте запрос, чтобы получить список всех сообществ на которые вы подписаны.

# %%
url = 'https://api.vk.com/method/groups.get'
params = {'access_token':'vk1.a.ngKxngcAGo06HiN2GwcHaZmGAlAXF73eSNdTstUsN4n49SmigSe9sy5kgd4g0Uit-beIMr1eC89fSrWarvEiHGkPtHPOunuPl7eb1bwCrwi2T16kz869NSTv8cEgiU-S2fV-newH62YZZGk7qMIxIboMCqw-RTARdkoJ1WX4QUDaBf3OjZhOUOzb37cg3v2wI2WfNV5mFtDCHgsw6Rf1cQ',
          'user_id' : '1270809',
          'extended' : '1', 
          'count' : '100',
          'v':'5.131'}
r = requests.get(url=url, params=params)
print(r.status_code)
# Out:
# 200

# %%
pprint(r.json())
# Out:
# {'response': {'count': 29,
#               'items': [{'id': 63781623,
#                          'is_admin': 0,
#                          'is_advertiser': 0,
#                          'is_closed': 0,
#                          'is_member': 1,
#                          'name': 'Подслушано Дубна',
#                          'photo_100': 'https://sun1.userapi.com/sun1-26/s/v1/ig2/Dzl2gdCNNgQ5mT47ps0Aj6axuwdHWAhQ2tPN6Oszq_vSCZqQr2oSg5AY_xmcL0pABjfac70ZjuDF8Du-k0iSNQWa.jpg?size=100x100&quality=95&crop=54,597,1128,1128&ava=1',
#                          'photo_200': 'https://sun1.userapi.com/sun1-26/s/v1/ig2/sPCsCj-svwFgNrhSo2I4eMVT5vAfZBVnR05WgDqMkqoym8W8XbU8B0UNLNzAI8dfDlgBhJbpPdC71MIxLyiQIu4A.jpg?size=200x200&quality=95&crop=54,597,1128,1128&ava=1',
#                          'photo_50': 'https://sun1.userapi.com/sun1-26/s/v1/ig2/U6JYjskMTbOyEYOC1wBtBZh94UFT-bRGlGAquB1xEv-tltasz98PCVMwG5uAfIPwS1p4UgldAe_bC1okteV3Rl2S.jpg?size=50x50&quality=95&crop=54,597,1128,1128&ava=1',
# ...
